# %%
pip install pandas
# Out:
# ...
#      -------------------------------------- 10.4/10.4 MB 160.3 kB/s eta 0:00:00
# ...
#      ------------------------------------ 499.4/499.4 kB 386.7 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import os

# %% [markdown]
# # Merging all the files together

# %%
all_file=[file for file in os.listdir("./Sales_Data")]


##Creating an empty dataframe
all_months_data=pd.DataFrame()

for file in all_file:
    df=pd.read_csv("./Sales_Data/" + file)  ###(+file) will read all the value stored in file variable
    all_months_data=pd.concat([all_months_data,df])

# %%
all_months_data
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 11681   259353      AAA Batteries (4-pack)                3       2.99
# 11682   259354                      iPhone                1        700
# 11683   259355                      iPhone                1        700
# 11684   259356      34in Ultrawide Monitor                1     379.99
# 11685   259357        USB-C Charging Cable                1      11.95
#
#            Order Date                         Purchase Address
# ...

# %% [markdown]
# # Turning all_months_data into a csv file

# %%
all_months_data.to_csv("all_months_data.csv",index=False)

# %%
all_data=pd.read_csv("all_months_data.csv")

# %%
all_data.tail()
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 186845   259353  AAA Batteries (4-pack)                3       2.99
# 186846   259354                  iPhone                1        700
# 186847   259355                  iPhone                1        700
# 186848   259356  34in Ultrawide Monitor                1     379.99
# 186849   259357    USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016

# %% [markdown]
# # Answering Questions

# %% [markdown]
# 1.What was the best months for sales and how much earned on that months

# %%
#Step1:Find out the month from date

# %%
all_data['months']=all_data["Order Date"].str[0:2]

# %%
all_data.tail()
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 186845   259353  AAA Batteries (4-pack)                3       2.99
# 186846   259354                  iPhone                1        700
# 186847   259355                  iPhone                1        700
# 186848   259356  34in Ultrawide Monitor                1     379.99
# 186849   259357    USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address months
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001     09
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016     09
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016     09
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016     09
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016     09

# %% [markdown]
# # Data Cleaning

# %%
NAN= all_data[all_data.isna().any(axis=1)]
all_data=all_data.dropna(how='all')   ##[how='all' means if all the columns are NAN then it will drop the row and how='any' means if there are only one column NAN then it will drop it]

# %%
NAN.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address  \
# 1         NaN     NaN              NaN        NaN        NaN              NaN
# 356       NaN     NaN              NaN        NaN        NaN              NaN
# 735       NaN     NaN              NaN        NaN        NaN              NaN
# 1433      NaN     NaN              NaN        NaN        NaN              NaN
# 1553      NaN     NaN              NaN        NaN        NaN              NaN
#
#      months
# 1       NaN
# 356     NaN
# 735     NaN
# 1433    NaN
# 1553    NaN

# %%
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address months
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001     04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215     04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001     04

# %%
#turning month string as an int value

# %% [markdown]
# Clean up 'Or' data

# %%
temp=all_data[all_data['months'].str[0:2]=='Or']

# %%
temp
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 519     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1149    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1155    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2878    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2893    Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...          ...      ...               ...         ...         ...
# 185164  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 185551  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186563  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186632  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186738  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase Address months
# 519     Purchase Address     Or
# 1149    Purchase Address     Or
# 1155    Purchase Address     Or
# ...

# %%
#Setting all data by removing or

# %%
all_data=all_data[all_data['months'].str[0:2]!='Or']

# %%
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address months
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001     04
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215     04
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     04
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     04
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001     04

# %%
all_data["months"]=all_data["months"].astype('int32')

# %% [markdown]
# # What was the best month for sales

# %% [markdown]
# Step1.Add a sales column by multiplying
#
# step2:Add a groupby function of months and find the highest months

# %%
all_data.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# months               int32
# dtype: object

# %%
#Converting object data into Integer

# %%
all_data['Quantity Ordered']=all_data['Quantity Ordered'].astype('int32')

# %%
all_data["Price Each"]=pd.to_numeric(all_data["Price Each"])    ##aanother way to converting into numeric value

# %%
all_data.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered      int32
# Price Each          float64
# Order Date           object
# Purchase Address     object
# months                int32
# dtype: object

# %%
#Add a sales column

# %%
all_data["sales"]=all_data['Quantity Ordered'] * all_data["Price Each"]

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  months   sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001       4   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215       4   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001       4   11.99

# %%
result=all_data.groupby('months').sum()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4764\1066563590.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   result=all_data.groupby('months').sum()

# %%
result
# Out:
#         Quantity Ordered  Price Each       sales
# months
# 1                  10903  1811768.38  1822256.73
# 2                  13449  2188884.72  2202022.42
# 3                  17005  2791207.83  2807100.38
# 4                  20558  3367671.02  3390670.24
# 5                  18667  3135125.13  3152606.75
# 6                  15253  2562025.61  2577802.26
# 7                  16072  2632539.56  2647775.76
# 8                  13448  2230345.42  2244467.88
# 9                  13109  2084992.09  2097560.13
# 10                 22703  3715554.83  3736726.88
# 11                 19798  3180600.68  3199603.20
# 12                 28114  4588415.41  4613443.34

# %%
#PLot a grraph for better visualization

# %%
import matplotlib.pyplot as plt

Months= range(1,13)
plt.bar(Months,result['sales'])
plt.xticks(Months)
plt.xlabel('Months')
plt.ylabel('Total sales')
plt.show()

# %% [markdown]
# # Oues2: What city has the highest number of sell

# %%
#Step1:add a city column

# %%
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  months  \
# ...

# %%
#Extracting city value from the address

# %%
def find_city(address):
    return address.split(',')[1]


def find_state(address):
    return address.split(',')[2].split(' ')[1]

all_data['city']=all_data["Purchase Address"].apply(lambda x:find_city(x)+ ' ' + find_state(x))    ####Here x represent all the row in permanent address

# %%
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  months  \
# ...

# %%
result=all_data.groupby('city').sum()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4764\1414460837.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   result=all_data.groupby('city').sum()

# %%
result
# Out:
#                    Quantity Ordered  Price Each  months       sales
# city
#  Atlanta GA                   16602  2779908.20  104794  2795498.58
#  Austin TX                    11153  1809873.61   69829  1819581.75
#  Boston MA                    22528  3637409.77  141112  3661642.01
#  Dallas TX                    16730  2752627.82  104620  2767975.40
#  Los Angeles CA               33289  5421435.23  208325  5452570.80
#  New York City NY             27932  4635370.83  175741  4664317.43
#  Portland ME                   2750   447189.25   17144   449758.27
#  Portland OR                  11303  1860558.22   70621  1870732.34
#  San Francisco CA             50239  8211461.74  315520  8262203.91
#  Seattle WA                   16553  2733296.01  104941  2747755.48

# %%
#Plotting the result

# %%
import matplotlib.pyplot as plt

Cities=[city for city,df in all_data.groupby('city')]
plt.bar(Cities,result['sales'])
plt.xticks(Cities,rotation='vertical',size=10)
plt.xlabel('City')
plt.ylabel('Total sales')
plt.show()

# %% [markdown]
# # Ques3: In what time we should advertise more to sell more product

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  months   sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001       4   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215       4   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001       4   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001       4   11.99
#
#               city
# 0        Dallas TX
# 2        Boston MA
# 3   Los Angeles CA
# 4   Los Angeles CA
# ...

# %%
all_data['Order Date']=pd.to_datetime(all_data['Order Date'])

# %%
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  months  \
# ...

# %%
all_data['hour']= all_data['Order Date'].dt.hour

# %%
all_data['Minute']= all_data['Order Date'].dt.minute

# %%
all_data
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 2        176559  Bose SoundSport Headphones                 1       99.99
# 3        176560                Google Phone                 1      600.00
# 4        176560            Wired Headphones                 1       11.99
# 5        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)                 3        2.99
# 186846   259354                      iPhone                 1      700.00
# 186847   259355                      iPhone                 1      700.00
# 186848   259356      34in Ultrawide Monitor                 1      379.99
# 186849   259357        USB-C Charging Cable                 1       11.95
#
#                 Order Date                         Purchase Address  months  \
# ...

# %%
hours=[Hour for Hour,df in all_data.groupby('hour')]
plt.plot(hours,all_data.groupby(['hour']).count())
plt.xticks(hours)
plt.xlabel("Hour")
plt.ylabel("number of orders")
plt.grid()
plt.show()

# %% [markdown]
# # Oues4: Which product are often sold together?

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  months   sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001       4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215       4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001       4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001       4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001       4   11.99
#
#               city  hour  Minute
# 0        Dallas TX     8      46
# ...

# %%
temp=all_data[all_data["Order ID"].duplicated(keep=False)]

# %%
temp.head(20)
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 3     176560                Google Phone                 1      600.00
# 4     176560            Wired Headphones                 1       11.99
# 18    176574                Google Phone                 1      600.00
# 19    176574        USB-C Charging Cable                 1       11.95
# 30    176585  Bose SoundSport Headphones                 1       99.99
# 31    176585  Bose SoundSport Headphones                 1       99.99
# 32    176586      AAA Batteries (4-pack)                 2        2.99
# 33    176586                Google Phone                 1      600.00
# 119   176672    Lightning Charging Cable                 1       14.95
# 120   176672        USB-C Charging Cable                 1       11.95
# 129   176681    Apple Airpods Headphones                 1      150.00
# 130   176681             ThinkPad Laptop                 1      999.99
# ...

# %%
temp['grouped']=temp.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
temp=temp[['Order ID','grouped']].drop_duplicates()
temp.head()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4764\1148701780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp['grouped']=temp.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#     Order ID                                            grouped
# 3     176560                      Google Phone,Wired Headphones
# 18    176574                  Google Phone,USB-C Charging Cable
# 30    176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 32    176586                AAA Batteries (4-pack),Google Phone
# 119   176672      Lightning Charging Cable,USB-C Charging Cable

# %%
from itertools import combinations
from collections import Counter

# %%
count=Counter()
for row in temp['grouped']:
    row_list=row.split(',')
    count.update(Counter(combinations(row_list,2)))

    
for key,value in count.most_common(10):
    print(key,value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1005
# ('Google Phone', 'USB-C Charging Cable') 987
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 414
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 160
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92

# %% [markdown]
# # Which product sold the most?

# %%
products=all_data.groupby('Product')

# %%
quantity=products.sum()['Quantity Ordered']
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4764\1321969979.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   quantity=products.sum()['Quantity Ordered']

# %%
#Showing the result using graph

# %%
Product=[x for x, df in products]

plt.bar(Product,quantity)
plt.xticks(Product,rotation='vertical',size=10)
plt.xlabel("Product Name")
plt.ylabel("Total Quantity")
plt.show()
